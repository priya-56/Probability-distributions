# %% [markdown]
# prac session 2

# %%
import pandas as pd

# %%
pd.DataFrame({'one': [50, 21], 'Two': [131, 2]})
# Out:
#    one  Two
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %% [markdown]
# **series**

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %% [markdown]
# **Reading**

# %%
wine_reviews = pd.read_csv("../content/product.csv")

# %%
wine_reviews.shape
# Out:
# (3, 4)

# %%
wine_reviews.head()
# Out:
#    Product A  Product B  Product C  Unnamed: 3
# 0         30         21          9         NaN
# 1         35         34          1         NaN
# 2         41         11         11         NaN

# %%
wine_reviews = pd.read_csv("/content/wine.csv")
wine_reviews.head()
# Out:
#   <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="u4T3BPUAV7HGoKnv7qqGIw">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xFIzIFKw.woff2)format('woff2');unicode-range:U+0460-052F  ... };this.gbar_=this.gbar_||{};(function(_){var window=this;
# 0                                               try{                                                                                                                                                                                                                                                                                                      ...                                                NaN
# ...

# %%
wine_reviews.head()
# Out:
#   <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="u4T3BPUAV7HGoKnv7qqGIw">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xFIzIFKw.woff2)format('woff2');unicode-range:U+0460-052F  ... };this.gbar_=this.gbar_||{};(function(_){var window=this;
# 0                                               try{                                                                                                                                                                                                                                                                                                      ...                                                NaN
# ...

# %%
wine_reviews = pd.read_csv("/content/wine.csv",index_col=0)
wine_reviews
# Out:
#                                                                   U+1C80-1C88  ... };this.gbar_=this.gbar_||{};(function(_){var window=this;
# <!DOCTYPE html><html><head><meta name="google" ...                             ...
# try{                                                                      NaN  ...                                                NaN
# /*                                                                        NaN  ...                                                NaN
#  Copyright The Closure Library Authors.                                   NaN  ...                                                NaN
#  SPDX-License-Identifier: Apache-2.0                                      NaN  ...                                                NaN
# */                                                                        NaN  ...                                                NaN
# ...

# %% [markdown]
# Exercise of Kaggle

# %%
import pandas as pd
fruit_sales=pd.DataFrame({'Apples':[35,21],'2018 Sales':[41,34]})
fruit_sales
# Out:
#    Apples  2018 Sales
# 0      35          41
# 1      21          34

# %%
import pandas as pd
fruit_sales=pd.DataFrame({'Apples':[30],'2018 Sales':[21]})
fruit_sales
# Out:
#    Apples  2018 Sales
# 0      30          21

# %%
import pandas as pd
ingredients = pd.Series(['4 cups','1 cup','2 large','1 can'],index=['Flour','Milk','Eggs','Spam'],name='Dinner')
ingredients
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %%
import pandas as pd
wine_reviews= pd.read_csv("../content/product.csv")
wine_reviews
# Out:
#    Product A  Product B  Product C  Unnamed: 3
# 0         30         21          9         NaN
# 1         35         34          1         NaN
# 2         41         11         11         NaN

# %%
animals = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
animals
# Out:
#         Cows  Goats
# Year 1    12     22
# Year 2    20     19
